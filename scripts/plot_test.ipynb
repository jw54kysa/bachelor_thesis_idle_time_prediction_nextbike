# %%
import matplotlib.pyplot as plt

x = ['2018','2019','2020','2021']
y = [182199,604598,681680,571895]

fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0)

# show values
for i, v in enumerate(y):
    ax.text(i, v+25, "%d" %v, ha="center")

ax.set_title('Rentals per Year')
plt.show()
