# %% [markdown]
# # Decompose TS Data
# ### in Trend, Seasonal, Resid

# %%
import pandas as pd

# 1 hauptbahnhof
# 7 augustusplatz

tsdata = pd.read_csv('../data/time_series_data/ts_data_881f1a8cb1fffff.csv')
del tsdata['list']
del tsdata['bike_count']
tsdata = tsdata.fillna(0)
tsdata['date'] = pd.to_datetime(tsdata['date'])
tsdata = tsdata.set_index(['date']).asfreq('D')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

series = tsdata
result = seasonal_decompose(series, model='additive')
print(result.trend)
print(result.seasonal)
print(result.resid)
print(result.observed)
# Out:
# date
# 2018-01-01           NaN
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04    716.714286
# 2018-01-05    804.000000
#                  ...
# 2021-12-26    931.428571
# 2021-12-27    914.714286
# 2021-12-28           NaN
# 2021-12-29           NaN
# 2021-12-30           NaN
# Freq: D, Name: trend, Length: 1460, dtype: float64
# date
# 2018-01-01    19.968742
# 2018-01-02    10.182995
# 2018-01-03     5.136756
# 2018-01-04    -1.310791
# 2018-01-05   -12.014087
#                 ...
# 2021-12-26   -20.845131
# 2021-12-27    19.968742
# 2021-12-28    10.182995
# 2021-12-29     5.136756
# 2021-12-30    -1.310791
# Freq: D, Name: seasonal, Length: 1460, dtype: float64
# date
# 2018-01-01           NaN
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04    -27.403495
# 2018-01-05    -67.985913
#                  ...
# 2021-12-26    271.416560
# 2021-12-27     13.316972
# 2021-12-28           NaN
# 2021-12-29           NaN
# 2021-12-30           NaN
# Freq: D, Name: resid, Length: 1460, dtype: float64
# date
# 2018-01-01     442.0
# 2018-01-02     736.0
# 2018-01-03     676.0
# 2018-01-04     688.0
# 2018-01-05     724.0
#                ...
# 2021-12-26    1182.0
# 2021-12-27     948.0
# 2021-12-28     881.0
# 2021-12-29     684.0
# 2021-12-30     504.0
# Freq: D, Length: 1460, dtype: float64

# %%
from matplotlib import pyplot


fig = result.plot()
fig.set_size_inches((16, 9))
#pyplot.xlim(('2021-01-01','2021-02-01'))
pyplot.show()

# %%
## Print Closeup of Seasonal for comparing to other hex


from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.plot(result.seasonal['2021-01-01':'2021-02-01'])
ax.set_ylabel('Seasonal')
fig.set_size_inches(16, 1.5)
plt.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.plot(result.seasonal['2021-01-01':'2021-02-01'])
ax.set_ylabel('Seasonal')
fig.set_size_inches(16, 1.5)
plt.show()
