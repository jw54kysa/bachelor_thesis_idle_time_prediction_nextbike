# %% [markdown]
# # Decompose TS Data
# ### in Trend, Seasonal, Resid

# %%
import pandas as pd

# 1 hauptbahnhof
# 7 augustusplatz

tsdata = pd.read_csv('../data/time_series_data/ts_data_881f1a164dfffff_Sachsenbrücke.csv')
del tsdata['list']
del tsdata['bike_count']
tsdata = tsdata.fillna(0)
tsdata['date'] = pd.to_datetime(tsdata['date'])
tsdata = tsdata.set_index(['date']).asfreq('D')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

series = tsdata
result = seasonal_decompose(series, model='additive')
print(result.trend)
print(result.seasonal)
print(result.resid)
print(result.observed)
# Out:
# date
# 2018-01-01            NaN
# 2018-01-02            NaN
# 2018-01-03            NaN
# 2018-01-04    1037.285714
# 2018-01-05    1046.857143
#                  ...
# 2021-12-26     665.142857
# 2021-12-27     697.714286
# 2021-12-28            NaN
# 2021-12-29            NaN
# 2021-12-30            NaN
# Freq: D, Name: trend, Length: 1460, dtype: float64
# date
# 2018-01-01    32.387683
# 2018-01-02    13.256163
# 2018-01-03    13.645397
# 2018-01-04     7.722847
# 2018-01-05   -21.720834
#                 ...
# 2021-12-26    -0.036768
# 2021-12-27    32.387683
# 2021-12-28    13.256163
# 2021-12-29    13.645397
# 2021-12-30     7.722847
# Freq: D, Name: seasonal, Length: 1460, dtype: float64
# date
# 2018-01-01           NaN
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04     43.991438
# 2018-01-05    -60.136309
#                  ...
# 2021-12-26    362.893911
# 2021-12-27    185.898032
# 2021-12-28           NaN
# 2021-12-29           NaN
# 2021-12-30           NaN
# Freq: D, Name: resid, Length: 1460, dtype: float64
# date
# 2018-01-01     844.0
# 2018-01-02    1439.0
# 2018-01-03    1112.0
# 2018-01-04    1089.0
# 2018-01-05     965.0
#                ...
# 2021-12-26    1028.0
# 2021-12-27     916.0
# 2021-12-28     515.0
# 2021-12-29     410.0
# 2021-12-30     422.0
# Freq: D, Length: 1460, dtype: float64

# %%
from matplotlib import pyplot


fig = result.plot()
fig.set_size_inches((16, 9))
#pyplot.xlim(('2021-01-01','2021-02-01'))
pyplot.show()

# %%
## Print Closeup of Seasonal for comparing to other hex


from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.plot(result.seasonal['2021-01-01':'2021-02-01'])
ax.set_ylabel('Seasonal')
fig.set_size_inches(16, 1.5)
plt.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.plot(result.seasonal['2021-01-01':'2021-02-01'])
ax.set_ylabel('Seasonal')
fig.set_size_inches(16, 1.5)
plt.show()
