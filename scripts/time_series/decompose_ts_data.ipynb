# %% [markdown]
# # Decompose TS Data
# ### in Trend, Seasonal, Resid

# %%
import pandas as pd

# 1 hauptbahnhof
# 7 augustusplatz

tsdata = pd.read_csv('../data/time_series_data/ts_data_881f1a1659fffff_LenePark.csv')
del tsdata['list']
del tsdata['bike_count']
tsdata = tsdata.fillna(0)
tsdata['date'] = pd.to_datetime(tsdata['date'])
tsdata = tsdata.set_index(['date']).asfreq('D')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

series = tsdata
result = seasonal_decompose(series, model='additive')
print(result.trend)
print(result.seasonal)
print(result.resid)
print(result.observed)
# Out:
# date
# 2018-01-01           NaN
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04    947.857143
# 2018-01-05    960.428571
#                  ...
# 2021-12-26    592.714286
# 2021-12-27    574.000000
# 2021-12-28           NaN
# 2021-12-29           NaN
# 2021-12-30           NaN
# Freq: D, Name: trend, Length: 1460, dtype: float64
# date
# 2018-01-01    12.173116
# 2018-01-02    -2.488573
# 2018-01-03   -11.997200
# 2018-01-04   -10.754082
# 2018-01-05   -26.484851
#                 ...
# 2021-12-26    57.072842
# 2021-12-27    12.173116
# 2021-12-28    -2.488573
# 2021-12-29   -11.997200
# 2021-12-30   -10.754082
# Freq: D, Name: seasonal, Length: 1460, dtype: float64
# date
# 2018-01-01           NaN
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04    501.896939
# 2018-01-05    152.056279
#                  ...
# 2021-12-26    454.212873
# 2021-12-27   -106.173116
# 2021-12-28           NaN
# 2021-12-29           NaN
# 2021-12-30           NaN
# Freq: D, Name: resid, Length: 1460, dtype: float64
# date
# 2018-01-01    1082.0
# 2018-01-02     441.0
# 2018-01-03    1029.0
# 2018-01-04    1439.0
# 2018-01-05    1086.0
#                ...
# 2021-12-26    1104.0
# 2021-12-27     480.0
# 2021-12-28     424.0
# 2021-12-29     381.0
# 2021-12-30     194.0
# Freq: D, Length: 1460, dtype: float64

# %%
from matplotlib import pyplot


fig = result.plot()
fig.set_size_inches((16, 9))
#pyplot.xlim(('2021-01-01','2021-02-01'))
pyplot.show()

# %%
## Print Closeup of Seasonal for comparing to other hex


from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.plot(result.seasonal['2021-01-01':'2021-02-01'])
ax.set_ylabel('Seasonal')
fig.set_size_inches(16, 1.5)
plt.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.plot(result.seasonal['2021-01-01':'2021-02-01'])
ax.set_ylabel('Seasonal')
fig.set_size_inches(16, 1.5)
plt.show()
