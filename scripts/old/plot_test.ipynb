# %%
import matplotlib.pyplot as plt

x = ['2018','2019','2020','2021']
y = [182199,604598,681680,571895]


fig, ax = plt.subplots()

# plotting daily data
ax.plot(x,y)
ax.set_xlabel('year')
ax.set_ylabel('rentals')

# show values

ax.set_title('Rentals per year')
plt.show()
#plt.savefig('../../data/results/rentaloveryears.png')
